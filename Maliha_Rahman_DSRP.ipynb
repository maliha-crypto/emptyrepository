# %% [markdown]
# <a href="https://colab.research.google.com/github/maliha-crypto/emptyrepository/blob/main/Maliha_Rahman_DSRP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# Repository + upload the data set
df = pd.read_csv("health_and_nutrition_combined_clean.csv")
df.head()
# Out:
#    Unnamed: 0   SEQN  RIAGENDR  RIDRETH3  RIDAGEYR   BMXHT  BMXBMI  BMXWT  \
# 0           0  83732         1         3        62  1845.0    27.8   94.8
# 1           1  83733         1         3        53  1714.0    30.8   90.4
# 2           2  83734         1         3        78  1701.0    28.8   83.4
# 3           3  83741         1         4        22  1654.0    28.0   76.6
# 4           4  83744         1         4        56  1794.0    33.6  108.3
#
#    RIDEXPRG  WTMEC4YR
# 0       NaN       NaN
# 1       NaN       NaN
# 2       NaN       NaN
# 3       NaN       NaN
# 4       NaN       NaN

# %%
# Change the Column names
# Change the codes to what they actually represent
# Drop uneccesary columns
# Check misisng values/data

# %%
# Rename the columns
df = df.rename(columns = {
    "SEQN": "Participant ID",
    "RIAGENDR": "Gender",
    "RIDRETH3": "Race Ethnicity",
    "RIDAGEYR": "Age",
    "BMXHT": "Height",
    "BMXBMI": "BMI",
    "BMXWT": "Weight",
    "RIDEXPRG": "Pregnancy Status",
    "WTMEC4YR": "Survey Weight"
})
df.columns
# Out:
# Index(['Unnamed: 0', 'Participant ID', 'Gender', 'Race Ethnicity', 'Age',
#        'Height', 'BMI', 'Weight', 'Pregnancy Status', 'Survey Weight'],
#       dtype='object')

# %%
# Drop the "Unnamed: 0" column
df = df.drop(columns=["Unnamed: 0"])
df.head()
# Out:
#    Participant ID  Gender  Race Ethnicity  Age  Height   BMI  Weight  \
# 0           83732       1               3   62  1845.0  27.8    94.8
# 1           83733       1               3   53  1714.0  30.8    90.4
# 2           83734       1               3   78  1701.0  28.8    83.4
# 3           83741       1               4   22  1654.0  28.0    76.6
# 4           83744       1               4   56  1794.0  33.6   108.3
#
#    Pregnancy Status  Survey Weight
# 0               NaN            NaN
# 1               NaN            NaN
# 2               NaN            NaN
# 3               NaN            NaN
# 4               NaN            NaN

# %%
# Change the codes to what they actually mean, gender
df["Gender"] = df["Gender"].replace({1: "Male", 2: "Female"})
df.head()
# Out:
#    Participant ID Gender  Race Ethnicity  Age  Height   BMI  Weight  \
# 0           83732   Male               3   62  1845.0  27.8    94.8
# 1           83733   Male               3   53  1714.0  30.8    90.4
# 2           83734   Male               3   78  1701.0  28.8    83.4
# 3           83741   Male               4   22  1654.0  28.0    76.6
# 4           83744   Male               4   56  1794.0  33.6   108.3
#
#    Pregnancy Status  Survey Weight
# 0               NaN            NaN
# 1               NaN            NaN
# 2               NaN            NaN
# 3               NaN            NaN
# 4               NaN            NaN

# %%
# Now same thing for "Race Ethnicity"
# Check which ones are actually used in the dataset
df["Race Ethnicity"].unique()
# Out:
# array([3, 4, 7, 6, 1])

# %%
df["Race Ethnicity"] = df["Race Ethnicity"].replace({
    1: "Mexican American",
    3: "Non-Hispanic White",
    4: "Non-Hispanic Black",
    6: "Non-Hispanic Asian",
    7: "Other Race, Including Multiracial"
})
df.head()
# Out:
#    Participant ID Gender      Race Ethnicity  Age  Height   BMI  Weight  \
# 0           83732   Male  Non-Hispanic White   62  1845.0  27.8    94.8
# 1           83733   Male  Non-Hispanic White   53  1714.0  30.8    90.4
# 2           83734   Male  Non-Hispanic White   78  1701.0  28.8    83.4
# 3           83741   Male  Non-Hispanic Black   22  1654.0  28.0    76.6
# 4           83744   Male  Non-Hispanic Black   56  1794.0  33.6   108.3
#
#    Pregnancy Status  Survey Weight
# 0               NaN            NaN
# 1               NaN            NaN
# 2               NaN            NaN
# 3               NaN            NaN
# 4               NaN            NaN

# %%
# Check NaNs
df.isnull().sum()
# Out:
# Participant ID          0
# Gender                  0
# Race Ethnicity          0
# Age                     0
# Height                136
# BMI                   157
# Weight                143
# Pregnancy Status     8442
# Survey Weight       10614
# dtype: int64

# %%
# Drop "Survey Weight"
df = df.drop(columns=["Survey Weight"])
df.head()
# Out:
#    Participant ID Gender      Race Ethnicity  Age  Height   BMI  Weight  \
# 0           83732   Male  Non-Hispanic White   62  1845.0  27.8    94.8
# 1           83733   Male  Non-Hispanic White   53  1714.0  30.8    90.4
# 2           83734   Male  Non-Hispanic White   78  1701.0  28.8    83.4
# 3           83741   Male  Non-Hispanic Black   22  1654.0  28.0    76.6
# 4           83744   Male  Non-Hispanic Black   56  1794.0  33.6   108.3
#
#    Pregnancy Status
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
# Drop "Pregnancy Status"
df = df.drop(columns=["Pregnancy Status"])
df.head()
# Out:
#    Participant ID Gender      Race Ethnicity  Age  Height   BMI  Weight
# 0           83732   Male  Non-Hispanic White   62  1845.0  27.8    94.8
# 1           83733   Male  Non-Hispanic White   53  1714.0  30.8    90.4
# 2           83734   Male  Non-Hispanic White   78  1701.0  28.8    83.4
# 3           83741   Male  Non-Hispanic Black   22  1654.0  28.0    76.6
# 4           83744   Male  Non-Hispanic Black   56  1794.0  33.6   108.3

# %%
df.columns
# Out:
# Index(['Participant ID', 'Gender', 'Race Ethnicity', 'Age', 'Height', 'BMI',
#        'Weight'],
#       dtype='object')

# %%
# Check for duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Participant ID      0
# Gender              0
# Race Ethnicity      0
# Age                 0
# Height            136
# BMI               157
# Weight            143
# dtype: int64

# %%
# Dropping the missing values in Height, BMI, and Weight
df = df.dropna()
df.isnull().sum()
# Out:
# Participant ID    0
# Gender            0
# Race Ethnicity    0
# Age               0
# Height            0
# BMI               0
# Weight            0
# dtype: int64

# %%
# Check height and then fix it
df["Height"].describe()
# Out:
# count    10457.000000
# mean      1662.120685
# std        101.272075
# min       1297.000000
# 25%       1587.000000
# 50%       1659.000000
# 75%       1736.000000
# max       2027.000000
# Name: Height, dtype: float64

# %%
df["Height"] = df["Height"] / 10
df["Height"].describe()
# Out:
# count    10457.000000
# mean       166.212068
# std         10.127208
# min        129.700000
# 25%        158.700000
# 50%        165.900000
# 75%        173.600000
# max        202.700000
# Name: Height, dtype: float64

# %%
df.head()
# Out:
#    Participant ID Gender      Race Ethnicity  Age  Height   BMI  Weight
# 0           83732   Male  Non-Hispanic White   62   184.5  27.8    94.8
# 1           83733   Male  Non-Hispanic White   53   171.4  30.8    90.4
# 2           83734   Male  Non-Hispanic White   78   170.1  28.8    83.4
# 3           83741   Male  Non-Hispanic Black   22   165.4  28.0    76.6
# 4           83744   Male  Non-Hispanic Black   56   179.4  33.6   108.3

# %%
df["Height"] = df["Height"] * 10
df.head()
# Out:
#    Participant ID Gender      Race Ethnicity  Age  Height   BMI  Weight
# 0           83732   Male  Non-Hispanic White   62  1845.0  27.8    94.8
# 1           83733   Male  Non-Hispanic White   53  1714.0  30.8    90.4
# 2           83734   Male  Non-Hispanic White   78  1701.0  28.8    83.4
# 3           83741   Male  Non-Hispanic Black   22  1654.0  28.0    76.6
# 4           83744   Male  Non-Hispanic Black   56  1794.0  33.6   108.3

# %%
df["Height"].describe()
# Out:
# count    10457.000000
# mean      1662.120685
# std        101.272075
# min       1297.000000
# 25%       1587.000000
# 50%       1659.000000
# 75%       1736.000000
# max       2027.000000
# Name: Height, dtype: float64

# %%
df["Height"] = df["Height"] / 10

# %%
df["Height"].describe()
# Out:
# count    10457.000000
# mean       166.212068
# std         10.127208
# min        129.700000
# 25%        158.700000
# 50%        165.900000
# 75%        173.600000
# max        202.700000
# Name: Height, dtype: float64

# %%
df.dtypes
# Out:
# Participant ID      int64
# Gender             object
# Race Ethnicity     object
# Age                 int64
# Height            float64
# BMI               float64
# Weight            float64
# dtype: object

# %%
df.head()
# Out:
#    Participant ID Gender      Race Ethnicity  Age  Height   BMI  Weight
# 0           83732   Male  Non-Hispanic White   62   184.5  27.8    94.8
# 1           83733   Male  Non-Hispanic White   53   171.4  30.8    90.4
# 2           83734   Male  Non-Hispanic White   78   170.1  28.8    83.4
# 3           83741   Male  Non-Hispanic Black   22   165.4  28.0    76.6
# 4           83744   Male  Non-Hispanic Black   56   179.4  33.6   108.3

# %%
import matplotlib.pyplot as plt

import pandas as pd

import numpy as np

import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Research Question: What demographic factors are associated with differences in BMI among adults in the NHANES dataset?

# %%
# BMI vary with age among adults in the dataset?
plt.scatter(df['Age'], df['BMI'])
plt.xlabel('Age')
plt.ylabel('BMI')
plt.title('BMI vs Age')
plt.show()

# %%
# Observations: little to no correlation between groups. Although

# %%
df["Age"].corr(df["BMI"])
# Out:
# np.float64(0.011896521245994324)

# %%
# checking the pregnancy category
df = pd.read_csv("health_and_nutrition_combined_clean.csv")
df.head()
# Out:
#    Unnamed: 0   SEQN  RIAGENDR  RIDRETH3  RIDAGEYR   BMXHT  BMXBMI  BMXWT  \
# 0           0  83732         1         3        62  1845.0    27.8   94.8
# 1           1  83733         1         3        53  1714.0    30.8   90.4
# 2           2  83734         1         3        78  1701.0    28.8   83.4
# 3           3  83741         1         4        22  1654.0    28.0   76.6
# 4           4  83744         1         4        56  1794.0    33.6  108.3
#
#    RIDEXPRG  WTMEC4YR
# 0       NaN       NaN
# 1       NaN       NaN
# 2       NaN       NaN
# 3       NaN       NaN
# 4       NaN       NaN

# %%
df["RIDEXPRG"].value_counts(dropna=False)
# Out:
# RIDEXPRG
# NaN    8442
# 2.0    2091
# 3.0      81
# Name: count, dtype: int64

# %%
df["RIDEXPRG"].unique()
# Out:
# array([nan,  2.,  3.])
